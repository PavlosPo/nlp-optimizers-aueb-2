# %%
import matplotlib.pyplot as plt

# Print advanced metrics from matplotlib
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('Test Plot Dummy')
plt.show()

# %%
# plot something more intresting like in bar plot
plt.bar([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('Test Plot Dummy')
plt.show()

# %%
print('Hello World!')
# Out:
# Hello World!
